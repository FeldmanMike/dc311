# %%
# %load_ext autoreload
# %autoreload 2

from itertools import combinations
import os

import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
import seaborn as sns

import helpers as hlp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Define CSV and read in data
#
# **TODO - read in both 2021 and 2022 files and concatenate**

# %%
# Define file
csv_file_21 = 'dc_311_2021_data.csv'
csv_file_22 = 'dc_311_2022_data.csv'

# %%
# Read in data
data_dir = os.path.join('..', '..', 'data', 'raw')

df_21 = pd.read_csv(os.path.join(data_dir, csv_file_21))
df_21['api_year'] = 2021

df_22 = pd.read_csv(os.path.join(data_dir, csv_file_22))
df_22['api_year'] = 2022

df = pd.concat([df_21, df_22], ignore_index=True)
# Out:
# /var/folders/rq/rs89ll8n2w93x8gnl0mtn7sw0000gn/T/ipykernel_10925/2072760993.py:4: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_21 = pd.read_csv(os.path.join(data_dir, csv_file_21))
# /var/folders/rq/rs89ll8n2w93x8gnl0mtn7sw0000gn/T/ipykernel_10925/2072760993.py:7: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22 = pd.read_csv(os.path.join(data_dir, csv_file_22))

# %% [markdown]
# ### Transform data to make EDA easier

# %%
# Convert all column names to lowercase
df.columns = [col.lower() for col in df.columns]

# %%
# Convert columns to date/time as appropriate
time_cols = ['adddate', 'resolutiondate', 'serviceduedate', 'serviceorderdate',
             'inspectiondate', 'gdb_from_date', 'gdb_to_date']
for col in time_cols:
    df[col] = pd.to_datetime(df[col], unit='ms', errors='coerce')

# %% [markdown]
# ### Profile dataframe

# %% [markdown]
# Initial observations:<br>
# - `objectid`: Confirmed that all values are unique.
# - `servicecode`: Maps basically 1:1 with `servicecodedescription`. Seven service codes have 2 descriptions, but all descriptions appear to be describing the same thing.
# - `servicecodedescription`: See `servicecode`. We can DROP from as a feature, as all information is included in `servicecode`. Or we can replace the service codes with the description.
# - `servicetypecodedescription`: Maps closely to `organizationacronym`. We can DROP as a feature for now (but maybe bring back later).
# - `organizationacronym`: KEEP as a feature.
# - `servicecallcount`: DROP. All values are 1.
# - `addate`: Important as feature. Can transform this to year, month, day of week, time of day.
# - `resolutiondate`: This is the target. Transform to `days to resolve`. The null values seem to provide real info.
# - `serviceduedate`:
# - `serviceorderdate`:
# - `serviceorderstatus`:
# - `status_code`:
# - `servicerequestid`:
# - `priority`:
# - `streetaddress`:
# - `xcoord`:
# - `ycoord`:
# - `latitude`:
# - `longitude`:
# - `city`:
# - `state`:
# - `zipcode`: Would not use to start. There are a lot of zip codes, and many have small number of cases. Very noisy.
# - `maraddressrepositoryid`:
# - `ward`: This is a good feature.
# - `details`:
# - `gis_id`:
# - `globalid`:
# - `creator`:
# - `created`:
# - `editor`:
# - `edited`:
# - `gdb_from_date`:
# - `gdb_to_date`:
# - `gdb_archive_oid`:
# - `api_year`:

# %% [markdown]
# ##### Service Codes

# %%
service_code_cols = ["servicecode", "servicecodedescription",
                    "servicetypecodedescription", "organizationacronym"]
code_df = df[service_code_cols]

# %%
col_pairs = list(combinations(list(code_df.columns), 2))
for pair in col_pairs:
    hlp.check_if_two_fields_are_one_to_one(code_df, pair[0], pair[1])
    print("-------------------------------------------------------------------")
    print("-------------------------------------------------------------------")
# Out:
# There are 7 values of `servicecode` that have more than one `servicecodedescription`:
# servicecode
# C62313m       2
# ILLEGALCON    2
# INSECTT01     2
# OUTODOR       2
# S0196         2
# SRC02         2
# VACPROP       2
# Name: servicecodedescription, dtype: int64
# ----------------------------------------------------
# All values of `servicecodedescription` have at most one `servicecode`.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# There are 2 values of `servicecode` that have more than one `servicetypecodedescription`:
# servicecode
# ILLEGALCON    2
# VACPROP       2
# Name: servicetypecodedescription, dtype: int64
# ----------------------------------------------------
# There are 20 values of `servicetypecodedescription` that have more than one `servicecode`:
# servicetypecodedescription
# 311- Call Center                                        6
# 311- Emergencies                                        2
# Adjudication Services                                   8
# DOH- Department Of Health                               2
# Department of Buildings (DOB)                           2
# Department of Energy and Environment                    7
# Department of Transportation                            2
# Dept of Consumer & Regulatory Affairs                   2
# Driver Vehicle Services                                11
# FEMS                                                    2
# HOMYDRPR- How Is My Driving Program                     2
# PEMA- Parking Enforcement Management Administration     6
# SIOD                                                    3
# SNOW                                                    7
# SWMA- Solid Waste Management Administration             6
# SWMA- Solid Waste Management Admistration              29
# Toa-Street & Bridge Maintenance                         2
# Transportation Operations Administration                3
# Transportation Policy & Planning Administration         2
# Urban Forrestry                                         4
# Name: servicecode, dtype: int64
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# There are 2 values of `servicecode` that have more than one `organizationacronym`:
# servicecode
# ILLEGALCON    2
# VACPROP       2
# Name: organizationacronym, dtype: int64
# ----------------------------------------------------
# There are 12 values of `organizationacronym` that have more than one `servicecode`:
# organizationacronym
# DCRA     2
# DDOT    19
# DFHV     2
# DGS      4
# DMV     19
# DOB      2
# DOEE     7
# DOH      2
# DPW     48
# FEMS     4
# ORM      3
# OUC     12
# Name: servicecode, dtype: int64
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# There are 2 values of `servicecodedescription` that have more than one `servicetypecodedescription`:
# servicecodedescription
# DCRA - Illegal Construction                  2
# DCRA - Vacant Private Property Inspection    2
# Name: servicetypecodedescription, dtype: int64
# ----------------------------------------------------
# There are 20 values of `servicetypecodedescription` that have more than one `servicecodedescription`:
# servicetypecodedescription
# 311- Call Center                                        6
# 311- Emergencies                                        2
# Adjudication Services                                   8
# DOH- Department Of Health                               3
# Department of Buildings (DOB)                           4
# Department of Energy and Environment                    8
# Department of Transportation                            2
# Dept of Consumer & Regulatory Affairs                   2
# Driver Vehicle Services                                11
# FEMS                                                    2
# HOMYDRPR- How Is My Driving Program                     2
# PEMA- Parking Enforcement Management Administration     6
# SIOD                                                    3
# SNOW                                                    8
# SWMA- Solid Waste Management Administration             6
# SWMA- Solid Waste Management Admistration              30
# Toa-Street & Bridge Maintenance                         2
# Transportation Operations Administration                3
# Transportation Policy & Planning Administration         2
# Urban Forrestry                                         4
# Name: servicecodedescription, dtype: int64
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# There are 2 values of `servicecodedescription` that have more than one `organizationacronym`:
# servicecodedescription
# DCRA - Illegal Construction                  2
# DCRA - Vacant Private Property Inspection    2
# Name: organizationacronym, dtype: int64
# ----------------------------------------------------
# There are 12 values of `organizationacronym` that have more than one `servicecodedescription`:
# organizationacronym
# DCRA     2
# DDOT    19
# DFHV     2
# DGS      4
# DMV     19
# DOB      4
# DOEE     8
# DOH      3
# DPW     51
# FEMS     4
# ORM      3
# OUC     12
# Name: servicecodedescription, dtype: int64
# -------------------------------------------------------------------
# -------------------------------------------------------------------
# All values of `servicetypecodedescription` have at most one `organizationacronym`.
# ----------------------------------------------------
# There are 5 values of `organizationacronym` that have more than one `servicetypecodedescription`:
# organizationacronym
# DDOT    8
# DMV     2
# DPW     4
# FEMS    3
# OUC     2
# Name: servicetypecodedescription, dtype: int64
# -------------------------------------------------------------------
# -------------------------------------------------------------------

# %%
code_df.head()
# Out:
#   servicecode            servicecodedescription  \
# 0       S0031                   Bulk Collection
# 1     BICYCLE                 Abandoned Bicycle
# 2       S05SL  Streetlight Repair Investigation
# 3       S0031                   Bulk Collection
# 4       S05SL  Streetlight Repair Investigation
#
#                   servicetypecodedescription organizationacronym
# 0  SWMA- Solid Waste Management Admistration                 DPW
# 1  SWMA- Solid Waste Management Admistration                 DPW
# 2   Transportation Operations Administration                DDOT
# 3  SWMA- Solid Waste Management Admistration                 DPW
# 4   Transportation Operations Administration                DDOT

# %% [markdown]
# All service codes have just one service code description, except for:<br>
# `C62313m`, `ILLEGALCON`, `OUTODOR`, `INSECTT01`, `SRC02`, `VACPROP`, `S0196`.<br>
#
# (Based on the below, it looks like the multiple code descriptions are rewordings of the same request type.)
#
# All service code descriptions are assigned to only one service code.

# %%
codes = ["C62313m", 'ILLEGALCON', "OUTODOR", "INSECTT01", "SRC02", "VACPROP", "S0196"]
for code in codes:
    print("-------------------------------------------------")
    print(f"Service code is: {code}")
    code_desc_df = code_df[code_df['servicecode'] == code]['servicecodedescription'].value_counts()
    print(code_desc_df)
# Out:
# -------------------------------------------------
# Service code is: C62313m
# servicecodedescription
# Christmas Tree Removal-Missed      1981
# Christmas Tree Removal - Missed       1
# Name: count, dtype: int64
# -------------------------------------------------
# Service code is: ILLEGALCON
# servicecodedescription
# DCRA - Illegal Construction    2174
# DOB - Illegal Construction      330
# Name: count, dtype: int64
# -------------------------------------------------
# Service code is: OUTODOR
# servicecodedescription
# DOEE - General Air Quality Concerns    241
# DOEE - Nuisance Odor Complaints         52
# Name: count, dtype: int64
# -------------------------------------------------
# Service code is: INSECTT01
# servicecodedescription
# Insect Treatment                         628
# Bee Treatment or Arboviral Inspection    275
# Name: count, dtype: int64
# -------------------------------------------------
# Service code is: SRC02
# servicecodedescription
# Snow/Ice Removal                      2123
# Snow/Ice Removal on Public Streets     107
# Name: count, dtype: int64
# -------------------------------------------------
# Service code is: VACPROP
# servicecodedescription
# DCRA - Vacant Private Property Inspection    6488
# DOB - Vacant Private Property Inspection      701
# Name: count, dtype: int64
# -------------------------------------------------
# Service code is: S0196
# servicecodedescription
# Leaf Season Collection     3262
# Leaf  Collection Missed    1502
# Name: count, dtype: int64

# %% [markdown]
# Is the `servicetypecodedescription` and `organizationacronym` relationship one-to-one?
#
# _Each service type code description is only assigned one organization acronym._<br>
# _Each organization is assigned to multiple service type codes. So organization is giving some order to service type code description._

# %%
orgs = ["DDOT", 'DMV', "DPW", "FEMS", "OUC"]
for org in orgs:
    print("-------------------------------------------------")
    print(f"Org is: {org}")
    org_df = code_df[code_df['organizationacronym'] == org]['servicetypecodedescription'].value_counts()
    print(org_df)
# Out:
# -------------------------------------------------
# Org is: DDOT
# servicetypecodedescription
# Transportation Operations Administration           53350
# Urban Forrestry                                    31600
# Toa-Trans Sys Mnt-Signs                            21575
# Toa-Street & Bridge Maintenance                    16019
# Department of Transportation                        8312
# Toa- Trans Sys Mnt                                  8169
# SIOD                                                6804
# Transportation Policy & Planning Administration     1807
# Name: count, dtype: int64
# -------------------------------------------------
# Org is: DMV
# servicetypecodedescription
# Driver Vehicle Services    15054
# Adjudication Services       1476
# Name: count, dtype: int64
# -------------------------------------------------
# Org is: DPW
# servicetypecodedescription
# SWMA- Solid Waste Management Admistration              318963
# PEMA- Parking Enforcement Management Administration    156300
# SWMA- Solid Waste Management Administration             39561
# SNOW                                                     5033
# Name: count, dtype: int64
# -------------------------------------------------
# Org is: FEMS
# servicetypecodedescription
# FEMS-Smoke Alarms      268
# FEMS                    76
# FEMS-Special Events      4
# Name: count, dtype: int64
# -------------------------------------------------
# Org is: OUC
# servicetypecodedescription
# 311- Call Center    20889
# 311- Emergencies       82
# Name: count, dtype: int64

# %% [markdown]
# ##### Dates

# %% [markdown]
# Observations:<br>
# - `adddate`: All records have an add date. Min and max are in expected years.
# - `resolutiondate`:
# - `serviceduedate`:
# - `serviceorderdate`:

# %% [markdown]
# ##### Understand `Days to Resolve` Causes

# %% [markdown]
# ##### `Days to Resolve` Initial Review

# %%
date_cols = ["servicecodedescription", "organizationacronym", "adddate",
            "resolutiondate", "serviceduedate", "serviceorderdate"]
date_df = df[date_cols]
date_df['days_to_resolve'] = (date_df['resolutiondate'] - date_df['adddate']).dt.days
# Out:
# /var/folders/rq/rs89ll8n2w93x8gnl0mtn7sw0000gn/T/ipykernel_10925/2810958849.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_df['days_to_resolve'] = (date_df['resolutiondate'] - date_df['adddate']).dt.days

# %%
date_df.shape
# Out:
# (747490, 7)

# %% [markdown]
# ~75% of 311 requests are completed within a week. Average time to complete is 25 days, versus a median of 3 days. Definitely a right-skewed distribution.
#
# If I'm someone calling 311, I may not be interested in days to resolve. What I care about most: what's the probability my request is an "easy" one, or a difficult one? Maybe: probability request completed in <5 days and request completed in >3 weeks?

# %%
date_df.describe()
# Out:
#                              adddate                 resolutiondate  \
# count                         747490                         740138
# mean   2022-01-12 18:45:28.402591232  2022-02-07 04:18:48.196868096
# min              2021-01-01 05:06:02            2021-01-01 05:07:01
# 25%       2021-07-26 19:32:42.500000            2021-08-11 17:03:59
# 50%              2022-01-11 22:09:28     2022-02-09 13:16:55.500000
# 75%    2022-07-10 21:14:29.750000128  2022-07-28 16:27:31.750000128
# max              2023-01-01 04:46:01            2024-09-25 21:03:09
# std                              NaN                            NaN
#
#                       serviceduedate               serviceorderdate  \
# count                         747243                         747490
# mean   2022-02-18 18:51:51.969645824  2022-01-12 18:45:28.402591232
# min              2021-01-03 20:29:16            2021-01-01 05:06:02
# 25%              2021-08-20 03:59:00     2021-07-26 19:32:42.500000
# 50%              2022-02-16 13:21:11            2022-01-11 22:09:28
# 75%              2022-08-11 21:37:41  2022-07-10 21:14:29.750000128
# max              2024-12-18 19:39:51            2023-01-01 04:46:01
# std                              NaN                            NaN
#
#        days_to_resolve
# count    740138.000000
# mean         25.803947
# min          -1.000000
# 25%           0.000000
# 50%           3.000000
# 75%           8.000000
# max        1348.000000
# std          92.773416

# %%
percentile_list = [0.01, 0.1, 0.25, 0.5, 0.6, 0.75, 0.85, 0.92, 0.95, 0.99, 0.999]
date_df['days_to_resolve'].quantile(percentile_list)
# Out:
# 0.010       0.0
# 0.100       0.0
# 0.250       0.0
# 0.500       3.0
# 0.600       5.0
# 0.750       8.0
# 0.850      18.0
# 0.920      63.0
# 0.950     139.0
# 0.990     522.0
# 0.999    1014.0
# Name: days_to_resolve, dtype: float64

# %% [markdown]
# ##### `Days to Resolve` by Service Code

# %%
df['days_to_resolve'] = (date_df['resolutiondate'] - date_df['adddate']).dt.days

# %%
agg_servicecode_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'servicecode', 'servicecodedescription'
)
agg_servicecode_df.sort_values('count_records', ascending=False).head(15)
# Out:
#        servicecode  median_days_to_resolve  std_dev_days_to_resolve  \
# 149980       S0031                     5.0                 2.286277
# 336638       S0261                     0.0                 3.455315
# 575369       S0441                     1.0                 3.503291
# 291151       S0181                     6.0                13.197451
# 431615       S0276                     2.0                45.129480
# 464808       S0311                     1.0                 9.880734
# 670695       S05SL                     3.0                28.679616
# 90309          RPP                     0.0                 1.241851
# 113395       S0000                     6.0                76.498590
# 642434       S0477                     7.0                 3.988949
# 696204    SIGNMISS                    41.0               189.142668
# 525571       S0346                     2.0                 9.385687
# 17933   DCGOVTINFO                     0.0                 0.000000
# 496960       S0321                     1.0                 3.431514
# 615273       S0457                     0.0                 4.692712
#
#         avg_days_to_resolve  count_records  \
# 149980             5.344159         137637
# 336638             0.127176          94977
# 575369             2.435934          34223
# 291151             9.398665          28062
# 431615            13.131304          26300
# 464808             2.244860          25686
# 670695             7.352746          23831
# 90309              0.124816          23086
# 113395            29.266967          22979
# 642434             7.169714          22769
# 696204           126.633110          21575
# 525571             4.635486          20659
# 17933              0.000000          19557
# 496960             2.613297          15258
# 615273             0.752795          13271
#
#                         servicecodedescription
# 149980                         Bulk Collection
# 336638                     Parking Enforcement
# 575369               Trash Collection - Missed
# 291151                         Illegal Dumping
# 431615                    Parking Meter Repair
# 464808         Rodent Inspection and Treatment
# 670695        Streetlight Repair Investigation
# 90309     Residential Parking Permit Violation
# 113395  Abandoned Vehicle - On Public Property
# 642434                    Scheduled Yard Waste
# 696204                           Roadway Signs
# 525571                  Sanitation Enforcement
# 17933                DC Government Information
# 496960           Recycling Collection - Missed
# 615273                         Tree Inspection

# %% [markdown]
# ##### `Days to Resolve` by Ward

# %% [markdown]
# There is some spread, but the medians are basically the same. Interestingly, the 8th Ward, which has the lowest median household income of the wards, has the lowest average time to resolve

# %%
agg_ward_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'ward'
)

# %%
agg_ward_df.sort_values('avg_days_to_resolve', ascending=False).head(30)
# Out:
#       ward  median_days_to_resolve  std_dev_days_to_resolve  \
# 12  Ward 5                     4.0               238.041383
# 10  Ward 2                     2.0               190.244724
# 9   Ward 1                    14.0               152.472948
# 8     Null                     5.0               134.526849
# 3        4                     4.0               113.724130
# 11  Ward 4                    10.0                58.790825
# 2        3                     4.0               102.684604
# 4        5                     4.0               104.603820
# 1        2                     2.0                93.423146
# 13  Ward 6                     7.0                64.306762
# 6        7                     4.0                90.421910
# 5        6                     3.0                79.697266
# 0        1                     3.0                72.240443
# 7        8                     2.0                71.187549
# 14  Ward 7                     1.5                 0.707107
#
#     avg_days_to_resolve  count_records
# 12           109.200000              5
# 10            98.142857             14
# 9             98.000000              3
# 8             59.947564           3552
# 3             33.806471         103823
# 11            31.888889              9
# 2             30.763829          62169
# 4             29.824726         112264
# 1             28.286897          83488
# 13            27.217391             23
# 6             23.007805          96348
# 5             21.253380         112291
# 0             20.690026          92242
# 7             17.737688          80566
# 14             1.500000              2

# %% [markdown]
# ##### `Days to Resolve` by Zip Code

# %%
agg_zip_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'zipcode'
)
agg_zip_df.sort_values('avg_days_to_resolve', ascending=False)
# Out:
#      zipcode  median_days_to_resolve  std_dev_days_to_resolve  \
# 56   20375.0                    31.0               236.285028
# 34   20217.0                     9.0               169.718216
# 68   20422.0                     5.0               209.419688
# 55   20374.0                     7.0               157.400826
# 59   20392.0                    16.0               148.506790
# 26   20057.0                     4.0               193.406171
# 100  20548.0                    16.0               107.024763
# 93   20535.0                     3.0               148.040020
# 24   20049.0                     2.5               166.524591
# 76   20451.0                     3.0               152.014113
# 91   20530.0                     0.0               219.202294
# 60   20401.0                     6.0               180.980369
# 41   20228.0                     3.0               121.337179
# 62   20408.0                     2.5               145.408740
# 28   20060.0                     0.0               169.305503
# 53   20372.0                    18.0                96.503554
# 29   20064.0                     3.0               153.796505
# 104  20554.0                    53.0                74.953319
# 102  20551.0                     1.0               141.383403
# 31   20201.0                     7.0               114.734802
# 67   20420.0                     0.0               135.890770
# 44   20237.0                     2.0               110.524378
# 107  20566.0                     3.0               110.840145
# 74   20441.0                     2.0                91.401998
# 11   20012.0                     4.0               117.815384
# 111  20585.0                     1.5               133.483729
# 12   20015.0                     5.0               118.495626
# 27   20059.0                     1.0               100.816968
# 14   20017.0                     5.0               119.399275
# 86   20515.0                     1.0                83.849924
# 32   20202.0                     5.5                57.367819
# 52   20319.0                     0.5                73.498911
# 10   20011.0                     4.0               111.074628
# 6    20007.0                     4.0               103.126131
# 15   20018.0                     4.0               110.431238
# 37   20223.0                     0.0                89.320734
# 4    20005.0                     2.0                99.104698
# 48   20250.0                     4.0                80.771515
# 7    20008.0                     4.0               100.782698
# 50   20260.0                     1.0               129.272708
# 22   20037.0                     2.0                95.210121
# 13   20016.0                     4.0                99.942649
# 109  20577.0                     6.0                58.188952
# 75   20442.0                     3.0                45.923850
# 3    20004.0                     2.0                97.599787
# 21   20036.0                     1.0                90.784651
# 35   20221.0                    27.0                      NaN
# 61   20405.0                     2.0                55.332804
# 92   20534.0                     2.5                66.477416
# 0    20001.0                     3.0                89.055319
# 17   20020.0                     4.0                88.735428
# 106  20565.0                     2.0                71.215268
# 16   20019.0                     4.0                90.971572
# 58   20390.0                     2.0                82.146770
# 1    20002.0                     3.0                84.509665
# 33   20210.0                     6.0                41.208554
# 70   20431.0                     0.5                84.950721
# 2    20003.0                     3.0                83.257538
# 8    20009.0                     2.0                78.271894
# 9    20010.0                     3.0                72.794417
# 5    20006.0                     1.0                75.184421
# 113  20591.0                     0.0                54.099515
# 90   20529.0                     0.0                36.500000
# 25   20052.0                     1.0                68.820375
# 83   20506.0                    18.0                      NaN
# 36   20222.0                     1.0                32.720064
# 115  20597.0                     2.0                63.134259
# 80   20500.0                     2.0                60.496281
# 82   20505.0                     6.0                18.316659
# 40   20227.0                     2.0                51.360004
# 43   20230.0                     0.0                51.174758
# 54   20373.0                     3.0                41.671594
# 71   20433.0                     0.0                36.256067
# 45   20240.0                     0.0                41.949951
# 64   20415.0                     1.0                46.764446
# 98   20546.0                     0.0                27.038671
# 20   20032.0                     0.0                61.682105
# 38   20224.0                     2.0                29.609179
# 84   20508.0                     3.0                18.270254
# 18   20024.0                     0.0                64.846873
# 77   20460.0                     6.0                15.666388
# 23   20045.0                     1.0                35.770565
# 57   20376.0                     2.5                22.199606
# 88   20526.0                     0.5                22.098709
# 105  20560.0                     3.0                19.627109
# 69   20427.0                     2.0                18.792317
# 94   20536.0                     0.0                32.683896
# 73   20439.0                     0.0                30.885124
# 72   20437.0                     6.0                10.904892
# 87   20520.0                     2.0                20.838142
# 110  20580.0                     0.0                33.979242
# 101  20549.0                     1.0                24.121289
# 89   20528.0                     5.0                 5.176872
# 103  20552.0                     0.5                17.546228
# 30   20071.0                     6.0                      NaN
# 46   20242.0                     2.5                 9.334077
# 114  20593.0                     0.0                22.061511
# 112  20590.0                     0.0                16.213172
# 65   20416.0                     0.0                 9.000000
# 108  20571.0                     0.0                17.414959
# 39   20226.0                     4.0                 5.656854
# 85   20510.0                     4.0                      NaN
# 81   20503.0                     4.0                 0.516398
# 97   20543.0                     0.0                27.915825
# 95   20540.0                     1.5                 4.289522
# 66   20418.0                     1.0                 5.298261
# 49   20254.0                     0.0                 5.007267
# 42   20229.0                     0.5                 2.872281
# 96   20542.0                     1.5                 2.121320
# 78   20463.0                     0.0                 2.683282
# 51   20306.0                     1.0                      NaN
# 19   20026.0                     1.0                      NaN
# 63   20410.0                     0.5                 0.983192
# 99   20547.0                     0.0                 1.613870
# 47   20245.0                     0.0                 0.751068
# 79   20472.0                     0.0                 0.000000
#
#      avg_days_to_resolve  count_records
# 56            200.714286             21
# 34            113.545455             12
# 68            106.080000             50
# 55             80.425000             40
# 59             79.533333             16
# 26             75.135593             60
# 100            74.400000             10
# 93             73.952381             21
# 24             70.142857             14
# 76             69.238095             21
# 91             68.468085             47
# 60             67.196721             62
# 41             66.600000             10
# 62             57.400000             60
# 28             57.175000             42
# 53             55.538462             13
# 29             53.193548            164
# 104            53.000000              2
# 102            48.866667             15
# 31             48.166667             30
# 67             44.838710             65
# 44             41.733333             16
# 107            38.275000             40
# 74             37.755556             45
# 11             37.204118          20268
# 111            37.083333             24
# 12             36.519116          16899
# 27             36.382456            292
# 14             36.152044          22803
# 86             34.875000             24
# 32             34.666667              7
# 52             33.357143             28
# 10             32.710361          79280
# 6              31.962809          27722
# 15             31.722422          25125
# 37             31.250000             32
# 4              31.186388          10122
# 48             31.038462             52
# 7              30.451945          17005
# 50             30.095238            105
# 22             29.816855           8533
# 13             29.568812          28386
# 109            28.704225             71
# 75             28.000000              3
# 3              27.690397           4862
# 21             27.235903           7608
# 35             27.000000              1
# 61             26.172414             29
# 92             25.805556             36
# 0              25.030539          58519
# 17             24.176788          47460
# 106            23.373626             91
# 16             23.314398          65180
# 58             23.300000             50
# 1              23.249768         103424
# 33             23.166667             24
# 70             22.754717            106
# 2              22.350838          45129
# 8              22.326289          51706
# 9              21.240013          39760
# 5              21.133841           3578
# 113            18.515152             33
# 90             18.250000              4
# 25             18.109328           1008
# 83             18.000000              1
# 36             17.538462             14
# 115            16.827586             58
# 80             16.300000             22
# 82             16.000000              9
# 40             15.875000             17
# 43             15.756757             38
# 54             15.391304             23
# 71             15.173913             46
# 45             14.935065             79
# 64             14.676190            106
# 98             14.384615             13
# 20             13.870000          44333
# 38             13.681818             23
# 84             13.571429             18
# 18             13.563355          14047
# 77             11.870370             56
# 23             11.250000             16
# 57             10.818182             22
# 88             10.666667             19
# 105            10.553459            163
# 69             10.522222             91
# 94             10.379747            158
# 73             10.090909             11
# 72              9.250000              4
# 87              8.117647             38
# 110             7.955224             67
# 101             7.645161             31
# 89              6.600000              6
# 103             6.181818             22
# 30              6.000000              1
# 46              5.625000              8
# 114             5.528455            124
# 112             4.812500             32
# 65              4.500000              4
# 108             4.137255             51
# 39              4.000000              2
# 85              4.000000              1
# 81              3.666667              6
# 97              3.375333           1127
# 95              3.000000              6
# 66              2.843750             32
# 49              2.545455             11
# 42              1.750000              4
# 96              1.500000              2
# 78              1.200000              5
# 51              1.000000              1
# 19              1.000000              1
# 63              0.833333              6
# 99              0.611111             18
# 47              0.307692             13
# 79              0.000000              8

# %% [markdown]
# ##### `Days to Resolve` by Organization

# %%
agg_org_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'organizationacronym'
)

# %%
agg_org_df.sort_values('avg_days_to_resolve', ascending=False).head(30)
# Out:
#    organizationacronym  median_days_to_resolve  std_dev_days_to_resolve  \
# 4                  DGS                    88.0               163.179464
# 11                 ORM                    38.0               236.995698
# 2                 DDOT                     4.0               149.319020
# 3                 DFHV                    13.0               177.856388
# 7                 DOEE                     7.0               122.317043
# 6                  DOB                    14.0                53.348836
# 9                  DPW                     3.0                71.760897
# 1                 DCRA                     5.0                27.982668
# 10                FEMS                     3.0                20.650217
# 5                  DMV                     6.0                 3.131191
# 0             DC Water                     0.0                21.818428
# 8                  DOH                     1.0                11.589183
# 12                 OUC                     0.0                23.944415
#
#     avg_days_to_resolve  count_records
# 4            176.127352            949
# 11           138.846952            986
# 2             66.353033         148469
# 3             53.500000             42
# 7             38.801569           1289
# 6             38.602690           6323
# 9             16.758962         521198
# 1             15.504639           3370
# 10             8.435159            348
# 5              6.046875          16530
# 0              2.916667             60
# 8              2.353487          26589
# 12             1.227744          21122

# %% [markdown]
# ##### Understand Unresolved Cases
#
# Unresolved cases don't generally seem to be instances of bad data. Generally, < 0.5% of a given service code is unresolved, but there are a small number of service codes where the percent of unresolved cases spikes, indicating that these are actually unresolved cases and not just accidental missing data.

# %%
unresolved_df = df[date_df['resolutiondate'].isnull()]

# %%
unresolved_df[['adddate']].describe()
# Out:
#                              adddate
# count                           7352
# mean   2022-04-08 13:38:43.269178368
# min              2021-01-02 19:37:57
# 25%              2021-10-13 21:33:18
# 50%       2022-06-07 17:18:02.500000
# 75%    2022-09-07 14:20:41.750000128
# max              2022-12-31 16:21:58

# %% [markdown]
# ~30% of unresolved cases are from 2021, remainder from 2022

# %%
percentile_list = [0, 0.01, 0.05, 0.1, 0.25, 0.3, 0.5, 0.7, 0.75, 0.9, 0.95, 0.99, 1]
unresolved_df['adddate'].quantile(percentile_list)
# Out:
# 0.00   2021-01-02 19:37:57.000000000
# 0.01   2021-01-28 06:04:08.910000128
# 0.05   2021-03-22 18:58:58.450000128
# 0.10   2021-06-03 17:59:48.200000000
# 0.25   2021-10-13 21:33:18.000000000
# 0.30   2022-01-24 04:29:15.400000000
# 0.50   2022-06-07 17:18:02.500000000
# 0.70   2022-09-02 16:10:23.600000000
# 0.75   2022-09-07 14:20:41.750000128
# 0.90   2022-10-19 17:50:14.900000000
# 0.95   2022-11-14 16:08:36.249999872
# 0.99   2022-12-17 15:56:17.069999872
# 1.00   2022-12-31 16:21:58.000000000
# Name: adddate, dtype: datetime64[ns]

# %% [markdown]
# Requests for repair seem to make up at least ~40% of unresolved cases and 6 of top 10 most-frequently-unresolved types of cases

# %%
unresolved_freq_df = pd.DataFrame(unresolved_df['servicecode'].value_counts()).reset_index()
service_code_freq_df = pd.DataFrame(df['servicecode'].value_counts()).reset_index()

merged_freq_df = unresolved_freq_df.merge(service_code_freq_df, on="servicecode", suffixes=('_unresolved', '_all'))
merged_freq_df['pct_unresolved'] = (merged_freq_df['count_unresolved'] /
                                    merged_freq_df['count_all'])
merged_freq_df['pct_of_all_unresolved']= (merged_freq_df['count_unresolved']/
                                          sum(merged_freq_df['count_unresolved']))
merged_freq_df['pct_all'] = merged_freq_df['count_all'] / sum(merged_freq_df['count_all'])

# %%
description_df = df[['servicecode', 'servicecodedescription']]
description_df = description_df.drop_duplicates(['servicecodedescription'])
merged_freq_df = merged_freq_df.merge(description_df, on='servicecode', how='left')

# %%
display(merged_freq_df.sort_values('pct_of_all_unresolved', ascending=False))

# %% [markdown]
# ##### `Days to Resolve` by Timeframe

# %%
df['add_year'] = df['adddate'].dt.year
df['add_month'] = df['adddate'].dt.month
df['add_day'] = df['adddate'].dt.dayofweek
df['add_hour'] = df['adddate'].dt.hour
df['added_during_work_hour'] = (df['add_hour'] >= 9) & (df['add_hour'] < 17)

# %%
agg_year_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'add_year'
)
agg_year_df.sort_values('avg_days_to_resolve', ascending=False)
# Out:
#    add_year  median_days_to_resolve  std_dev_days_to_resolve  \
# 0      2021                     3.0               104.604858
# 1      2022                     3.0                79.835806
# 2      2023                     5.0                83.891669
#
#    avg_days_to_resolve  count_records
# 0            30.317082         360810
# 1            21.560408         386631
# 2            18.979592             49

# %%
agg_month_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'add_month'
)
agg_month_df.sort_values('avg_days_to_resolve', ascending=False)
# Out:
#     add_month  median_days_to_resolve  std_dev_days_to_resolve  \
# 1           2                     3.0               103.305521
# 4           5                     3.0               101.753839
# 8           9                     3.0                88.945239
# 2           3                     3.0               105.986587
# 7           8                     3.0                91.951710
# 3           4                     3.0               104.979293
# 5           6                     3.0                96.928076
# 6           7                     3.0                94.415214
# 9          10                     3.0                81.806184
# 10         11                     4.0                78.624091
# 0           1                     4.0                90.398404
# 11         12                     4.0                67.331889
#
#     avg_days_to_resolve  count_records
# 1             28.413346          46432
# 4             27.425322          61441
# 8             27.423319          70137
# 2             27.270441          58237
# 7             26.898725          75627
# 3             26.841034          58006
# 5             26.342920          70892
# 6             26.224053          72362
# 9             25.557740          71019
# 10            24.259598          55420
# 0             22.944478          52748
# 11            19.024485          55169

# %%
agg_day_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'add_day'
)
agg_day_df.sort_values('avg_days_to_resolve', ascending=False)
# Out:
#    add_day  median_days_to_resolve  std_dev_days_to_resolve  \
# 6        6                     3.0                97.278225
# 3        3                     4.0                92.922331
# 1        1                     2.0                92.427911
# 4        4                     3.0                93.107418
# 2        2                     4.0                93.601571
# 0        0                     3.0                91.210324
# 5        5                     3.0                90.435991
#
#    avg_days_to_resolve  count_records
# 6            28.182878          46035
# 3            26.326748         128452
# 1            26.023715         139490
# 4            26.022994         112687
# 2            25.468272         134338
# 0            25.204703         125605
# 5            23.971570          60883

# %%
agg_workhour_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'added_during_work_hour'
)
agg_workhour_df.sort_values('added_during_work_hour', ascending=False)
# Out:
#    added_during_work_hour  median_days_to_resolve  std_dev_days_to_resolve  \
# 1                    True                     3.0                89.985473
# 0                   False                     3.0                95.016523
#
#    avg_days_to_resolve  count_records
# 1            24.715047         339014
# 0            26.707972         408476

# %%
agg_hour_df = hlp.summarize_relationship_between_target_and_variable(
    df, 'add_hour'
)
agg_hour_df.sort_values('avg_days_to_resolve', ascending=False)
# Out:
#     add_hour  median_days_to_resolve  std_dev_days_to_resolve  \
# 9          9                     3.0               104.090259
# 5          5                     3.0               100.291138
# 1          1                     3.0               100.411702
# 2          2                     3.0                99.520421
# 19        19                     4.0                96.901039
# 18        18                     4.0                94.899019
# 4          4                     3.0                97.479173
# 20        20                     3.0                96.714195
# 6          6                     3.0                90.549238
# 17        17                     4.0                93.790713
# 16        16                     3.0                93.771907
# 15        15                     3.0                92.289584
# 7          7                     3.0                89.460008
# 3          3                     3.0                96.970723
# 22        22                     3.0                93.937592
# 23        23                     3.0                94.918583
# 14        14                     3.0                91.564793
# 8          8                     3.0                82.982684
# 21        21                     3.0                91.259579
# 0          0                     3.0                90.212855
# 12        12                     2.0                87.609973
# 13        13                     3.0                86.995810
# 11        11                     1.0                80.455979
# 10        10                     2.0                79.481777
#
#     avg_days_to_resolve  count_records
# 9             30.791559           2355
# 5             30.066143           3616
# 1             28.245553          17401
# 2             28.183790          13612
# 19            27.817429          57237
# 18            27.679094          60171
# 4             27.344454           5957
# 20            27.128827          50140
# 6             26.929559           2285
# 17            26.537456          62256
# 16            26.230367          64085
# 15            25.997401          66414
# 7             25.844776           1710
# 3             25.842201          10037
# 22            25.802638          33600
# 23            25.759234          26250
# 14            25.256051          68768
# 8             25.168784           1670
# 21            25.079701          41801
# 0             23.845491          20733
# 12            23.562093          44507
# 13            23.138910          65078
# 11            21.897339          21521
# 10            21.659875           6286
